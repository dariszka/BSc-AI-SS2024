# %% [markdown]
# Name | Matr.Nr. | Due Date
# :--- | ---: | ---:
# Darina Petrova | 12230205 | 29.04.2024, 10:00

# %% [markdown]
# <h1 style="color:rgb(0,120,170)">Hands-on AI II</h1>
# <h2 style="color:rgb(0,120,170)">Unit 3 &ndash; Recurrent Neural Networks (Assignment)</h2>

# %% [markdown]
# <b>Authors:</b> B. Schäfl, S. Lehner, J. Brandstetter, E. Kobler, A. Schörgenhumer, R. Dangl<br>
# <b>Date:</b> 23-04-2024
#
# This file is part of the "Hands-on AI II" lecture material. The following copyright statement applies to all code within this file.
#
# <b>Copyright statement:</b><br>
# This material, no matter whether in printed or electronic form, may be used for personal and non-commercial educational use only. Any reproduction of this material, no matter whether as a whole or in parts, no matter whether in printed or in electronic form, requires explicit prior acceptance of the authors.

# %% [markdown]
# <h3 style="color:rgb(0,120,170)">How to use this notebook</h3>
# This notebook is designed to run from start to finish. There are different tasks (displayed in <span style="color:rgb(248,138,36)">orange boxes</span>) which require your contribution (in form of code, plain text, ...). Most/All of the supplied functions are imported from the file <code>u3_utils.py</code> which can be seen and treated as a black box. However, for further understanding, you can look at the implementations of the helper functions. In order to run this notebook, the packages which are imported at the beginning of <code>u3_utils.py</code> need to be installed.

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Important:</b> Set the random seed with <code>u3.set_seed(23)</code> to enable reproducible results in all tasks that incorporate randomness (e.g., t-SNE, splitting data intro train and test sets, initializing weights of a neural network, running the model optimization with random batches, etc.). You must use <code>23</code> as seed.
# </div>

# %%
# Import pre-defined utilities specific to this notebook.
import u3_utils as u3

# Import additional utilities needed in this notebook.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import torch

# Set default plotting style.
sns.set_theme()

# Setup Jupyter notebook (warning: this may affect all Jupyter notebooks running on the same Jupyter server).
u3.setup_jupyter()

# Check minimum versions.
u3.check_module_versions()
# Out:
# Installed Python version: 3.10 (✓)
# Installed numpy version: 1.25.2 (✓)
# Installed pandas version: 2.0.3 (✓)
# Installed PyTorch version: 2.1.1+cu118 (✓)
# Installed matplotlib version: 3.7.3 (✓)
# Installed seaborn version: 0.13.2 (✓)

# %% [markdown]
# <a name="exercise-latch-sequence-set"></a><h2>The Latch Sequence Data Set</h2>
# <p>In the accompanying excercise class, the <i>latch task</i> was presented. You'll be working with the same data set in this assignment. The original latch task was introduced by Hochreiter and Mozer:
# <center>
#     <cite>Sepp Hochreiter, Michael Mozer, 2001. A discrete probabilistic memory model for discovering dependencies in time. Artificial Neural Networks -- ICANN 2001, 13, pp.661-668.</cite>
# </center></p>
#
# <p>The essence of this task is that a sequence of inputs is presented, beginning with one of two symbols, <b>A</b> or <b>B</b>, and after a variable number of time steps, the model has to output a corresponding symbol. Thus, the task requires memorizing the original input over time. It has to be noted that in the <i>original</i> task desription, both class-defining symbols must only appear at the first position of an instance.</p>
#
# <p>The modified version of this task used in this assignment is identical to the one discussed during the accompanying exercise, with the difference of a higher amount of possible targets. Defining arguments are:
#
# <table>
#     <tr>
#         <th>Argument</th>
#         <th>Value (used in this assignment)</th>
#         <th>Description</th>
#     </tr>
#     <tr>
#         <th><code>num_samples</code></th>
#         <th>4096</th>
#         <th>Amount of samples of the full dataset.</th>
#     </tr>
#     <tr>
#         <th><code>num_instances</code></th>
#         <th>64</th>
#         <th>Amount of instances per sample (sample length).</th>
#     </tr>
#     <tr>
#         <th><code>num_characters</code></th>
#         <th>26</th>
#         <th>Amount of different characters (size of the one-hot encoded vector).</th>
#     </tr>
#     <tr>
#         <th><code>num_targets</code></th>
#         <th>25</th>
#         <th>Amount of different characters used as possible targets.</th>
#     </tr>
#     <tr>
#         <th><code>seed</code></th>
#         <th>23</th>
#         <th>Random seed used to generate the samples of the data set.</th>
#     </tr>
# </table></p>

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 1.1. [8 Points]</b>
#     <ul>
#         <li>Generate a <i>latch sequence</i> data set with the properties as described in the table <i>above</i>.</li>
#         <li>Visualize the last sequence of the data set in <i>tabular</i> form, with all $1$ in <b style="color:green">bold green</b> and all $0$ in <span style="font-weight: lighter">lighter</span> default font color.</li>
#         <li>Visualize the <i>first</i> $32$ samples in a heatmap, once <i>without</i> and once <i>with</i> a corresponding prefix-mask.</li>
#         <li>Interpreting the previous visualizations, which <i>character</i> of the chosen alphabet determines the <i>prefix</i>?</li>
#     </ul>
# </div>

# %%
# your code goes here
data_latch = u3.LatchSequenceSet(
    num_samples=4096,
    num_instances=64,
    num_characters=26,
    num_targets=25,
    seed=23
)

data_sample = pd.DataFrame(data_latch[-1][0].transpose(0, 1)).astype(int)
data_sample.index = [chr(65 + i) for i in data_sample.index]

first32_samples = data_latch[:32][0]
data_heatmap = pd.DataFrame(first32_samples.argmax(dim=2))

u3.plot_heatmap(data=data_heatmap, figsize=(14, 7))
u3.plot_heatmap(data=data_heatmap, prefix_mask=True, prefix_index=data_latch.num_targets, figsize=(14, 7))

data_sample.style.applymap(lambda x: 'color: green; font-weight: bold' if x == 1 else 'color: default; font-weight: lighter')
# Out:
# <style type="text/css">
# #T_0644f_row0_col0, #T_0644f_row0_col1, #T_0644f_row0_col2, #T_0644f_row0_col3, #T_0644f_row0_col4, #T_0644f_row0_col5, #T_0644f_row0_col6, #T_0644f_row0_col7, #T_0644f_row0_col8, #T_0644f_row0_col9, #T_0644f_row0_col10, #T_0644f_row0_col11, #T_0644f_row0_col12, #T_0644f_row0_col13, #T_0644f_row0_col15, #T_0644f_row0_col16, #T_0644f_row0_col17, #T_0644f_row0_col18, #T_0644f_row0_col19, #T_0644f_row0_col20, #T_0644f_row0_col21, #T_0644f_row0_col22, #T_0644f_row0_col23, #T_0644f_row0_col25, #T_0644f_row0_col26, #T_0644f_row0_col27, #T_0644f_row0_col28, #T_0644f_row0_col29, #T_0644f_row0_col30, #T_0644f_row0_col31, #T_0644f_row0_col32, #T_0644f_row0_col34, #T_0644f_row0_col35, #T_0644f_row0_col36, #T_0644f_row0_col37, #T_0644f_row0_col38, #T_0644f_row0_col39, #T_0644f_row0_col40, #T_0644f_row0_col41, #T_0644f_row0_col42, #T_0644f_row0_col43, #T_0644f_row0_col44, #T_0644f_row0_col45, #T_0644f_row0_col46, #T_0644f_row0_col47, #T_0644f_row0_col48, #T_0644f_row0_col49, #T_0644f_row0_col50, #T_0644f_row0_col51, #T_0644f_row0_col52, #T_0644f_row0_col53, #T_0644f_row0_col54, #T_0644f_row0_col55, #T_0644f_row0_col56, #T_0644f_row0_col57, #T_0644f_row0_col58, #T_0644f_row0_col59, #T_0644f_row0_col60, #T_0644f_row0_col61, #T_0644f_row0_col62, #T_0644f_row0_col63, #T_0644f_row1_col0, #T_0644f_row1_col1, #T_0644f_row1_col2, #T_0644f_row1_col3, #T_0644f_row1_col4, #T_0644f_row1_col5, #T_0644f_row1_col6, #T_0644f_row1_col7, #T_0644f_row1_col8, #T_0644f_row1_col9, #T_0644f_row1_col10, #T_0644f_row1_col11, #T_0644f_row1_col12, #T_0644f_row1_col13, #T_0644f_row1_col14, #T_0644f_row1_col15, #T_0644f_row1_col16, #T_0644f_row1_col17, #T_0644f_row1_col18, #T_0644f_row1_col19, #T_0644f_row1_col20, #T_0644f_row1_col21, #T_0644f_row1_col22, #T_0644f_row1_col23, #T_0644f_row1_col24, #T_0644f_row1_col25, #T_0644f_row1_col26, #T_0644f_row1_col27, #T_0644f_row1_col28, #T_0644f_row1_col29, #T_0644f_row1_col30, #T_0644f_row1_col31, #T_0644f_row1_col32, #T_0644f_row1_col33, #T_0644f_row1_col34, #T_0644f_row1_col35, #T_0644f_row1_col36, #T_0644f_row1_col37, #T_0644f_row1_col38, #T_0644f_row1_col39, #T_0644f_row1_col40, #T_0644f_row1_col41, #T_0644f_row1_col42, #T_0644f_row1_col43, #T_0644f_row1_col44, #T_0644f_row1_col45, #T_0644f_row1_col46, #T_0644f_row1_col47, #T_0644f_row1_col48, #T_0644f_row1_col49, #T_0644f_row1_col51, #T_0644f_row1_col52, #T_0644f_row1_col53, #T_0644f_row1_col54, #T_0644f_row1_col55, #T_0644f_row1_col56, #T_0644f_row1_col58, #T_0644f_row1_col60, #T_0644f_row1_col61, #T_0644f_row1_col62, #T_0644f_row1_col63, #T_0644f_row2_col0, #T_0644f_row2_col1, #T_0644f_row2_col2, #T_0644f_row2_col3, #T_0644f_row2_col4, #T_0644f_row2_col5, #T_0644f_row2_col6, #T_0644f_row2_col7, #T_0644f_row2_col8, #T_0644f_row2_col9, #T_0644f_row2_col10, #T_0644f_row2_col11, #T_0644f_row2_col13, #T_0644f_row2_col14, #T_0644f_row2_col15, #T_0644f_row2_col16, #T_0644f_row2_col17, #T_0644f_row2_col18, #T_0644f_row2_col19, #T_0644f_row2_col20, #T_0644f_row2_col21, #T_0644f_row2_col22, #T_0644f_row2_col23, #T_0644f_row2_col24, #T_0644f_row2_col25, #T_0644f_row2_col26, #T_0644f_row2_col28, #T_0644f_row2_col29, #T_0644f_row2_col30, #T_0644f_row2_col31, #T_0644f_row2_col32, #T_0644f_row2_col33, #T_0644f_row2_col34, #T_0644f_row2_col35, #T_0644f_row2_col36, #T_0644f_row2_col37, #T_0644f_row2_col38, #T_0644f_row2_col39, #T_0644f_row2_col40, #T_0644f_row2_col41, #T_0644f_row2_col42, #T_0644f_row2_col43, #T_0644f_row2_col44, #T_0644f_row2_col45, #T_0644f_row2_col46, #T_0644f_row2_col47, #T_0644f_row2_col48, #T_0644f_row2_col49, #T_0644f_row2_col50, #T_0644f_row2_col51, #T_0644f_row2_col52, #T_0644f_row2_col53, #T_0644f_row2_col54, #T_0644f_row2_col55, #T_0644f_row2_col56, #T_0644f_row2_col57, #T_0644f_row2_col58, #T_0644f_row2_col59, #T_0644f_row2_col60, #T_0644f_row2_col61, #T_0644f_row2_col62, #T_0644f_row2_col63, #T_0644f_row3_col0, #T_0644f_row3_col1, #T_0644f_row3_col2, #T_0644f_row3_col3, #T_0644f_row3_col4, #T_0644f_row3_col5, #T_0644f_row3_col6, #T_0644f_row3_col7, #T_064 ...

# %% [markdown]
# Character 'z' determines the prefix

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 1.2. [7 Points]</b>
#     <ul>
#         <li>Linearly split the data set into a <i>training</i> and a <i>test</i> set in a ratio of $4 : 1$ (use a <code>SubsetRandomSampler</code> and a batch size of $64$).</li>
#         <li>Compute and print the <i>amount of samples</i> of each of the respective sets and verify the $4 : 1$ split.</li>
#         <li>Visualize the <i>character counts</i> of the <i>first</i> training minibatch appropriately. What is the count of the <i>prefix</i> character? Provide a formula as a function of the <i>batch_size</i> to compute the count of the <i>prefix</i> character.</li>
#     </ul>
# </div>

# %%
# your code goes here

batch_size = 64
test_size = data_latch.num_samples // 5

u3.set_seed(23)

sampler_train = torch.utils.data.SubsetRandomSampler(range(test_size, data_latch.num_samples))
data_loader_train = torch.utils.data.DataLoader(
    dataset=data_latch,
    batch_size=batch_size,
    sampler=sampler_train
)

sampler_test = torch.utils.data.SubsetRandomSampler(range(test_size))
data_loader_test = torch.utils.data.DataLoader(
    dataset=data_latch,
    batch_size=batch_size,
    sampler=sampler_test
)

print(f'The training set consists of "{len(sampler_train)}" samples, '
      f'whereas the test set comprises "{len(sampler_test)}" samples.')

assert len(data_loader_train) == 4*len(data_loader_test)

u3.set_seed(23)

data_heatmap = next(iter(data_loader_train))[0]
data_heatmap = pd.DataFrame(data_heatmap.argmax(dim=2))
data_histogram = data_heatmap.to_numpy().flatten()

fig, ax = plt.subplots(figsize=(14, 7))
palette = sns.color_palette("hsv", len(set(data_histogram)))
count_plot = sns.countplot(x=data_histogram, ax=ax, palette=palette, hue=data_histogram, legend=False)

ticks = [i for i in range(data_latch.num_characters)]
labels = [chr(65 + i) for i in range(len(ticks))]
ax.set_xticks(ticks)
ax.set_xticklabels(labels)
ax.set_xlabel('Character')
ax.set_ylabel('Count')
plt.show()

print('Count of prefix character is 128, which is 2*num_instances')
# Out:
# The training set consists of "3277" samples, whereas the test set comprises "819" samples.
# Count of prefix character is 128, which is 2*num_instances

# %% [markdown]
# <a name="exercise-latch-cnn"></a><h2>Tackling Sequence Data with CNNs</h2>
# <p>During the accompanying exercise class, a <i>dense feed-forward</i> network was presented as some kind of baseline. Afterwards, recurrent architectures were applied. In this exercise, you'll be tasked with implementing a <i>convolutional</i> architecture for handling sequence data.</p>

# %% [markdown]
# <div class="alert alert-warning">
#     The following code snippet is taken from the accompanying exercise notebook. You do not need to modify it for this assignment.
# </div>

# %%
class TheMightyDice(torch.nn.Module):
    """
    Dice roll "network" tailored to deliver random outcomes.
    """
    
    def __init__(self, output_size: int):
        super().__init__()
        self.__output_size = output_size
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return torch.rand(size=(x.shape[0], self.__output_size), device=x.device)


def count_parameters(model: torch.nn.Module, only_trainable: bool = True) -> int:
    """
    Count (trainable) paramaters of specified model.
    
    :param model: model for which to compute the amount of (trainable) parameters
    :param only_trainable: only include trainable parameters in total count
    :return: amount of (trainable) parameters of the specified model
    """
    return sum(parameter.numel() for parameter in model.parameters() if any(
        (not only_trainable, only_trainable and parameter.requires_grad)))

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 2.1. [7 Points]</b>
#     <ul>
#         <li>Test a <code>TheMightyDice</code> instance on the latch sequence <i>test</i> set. Do you expect this result? Comment on your answer.</li>
#         <li>Assume <i>uniformly</i> distributed targets. If a model would <i>always</i> predict the same class, what would the accuracy be?</li>
#     </ul>
# </div>

# %%
# your code goes here
u3.set_seed(23)
target_device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

performance = u3.test_network(
    model=TheMightyDice(output_size=data_latch.num_targets).to(device=target_device),
    data_loader=data_loader_test,
    device=target_device
)
print(f'Final loss: {performance[0]:.4f} / Final accuracy: {performance[1]:.4f}')
# Out:
# Final loss: 0.0515 / Final accuracy: 0.0562

# %% [markdown]
# The answer is understandable, we'd expect accuracy of 1/25 = 4% for random guessing, we get 5.6% here which is close enough (it fluctuates for different seeds).
#
# If targets are uniformly distributed, each class will have 1/25 samples. If we pick one, we'd correctly guess each one of its samples and nothing else correctly, so we'd have 1/25 = 4% accuracy.

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 2.2. [15 Points]</b>
#     <ul>
#         <li>Implement a class <code>CNN</code> with the following architecture:</li>
#     </ul>
#     <table style="text-align:center;vertical-align:middle">
#         <th>Position</th>
#         <th>Element</th>
#         <th>Comment</th>
#         <tr>
#             <td>0</td>
#             <td>input</td>
#             <td>-</td>
#         </tr>
#         <tr>
#             <td>1</td>
#             <td><a href="https://pytorch.org/docs/stable/generated/torch.nn.Conv1d.html">1D convolution</a></td>
#             <td>$256$ output channels and a configurable kernel size (specified as an argument to <code>__init__</code>)</td>
#         </tr>
#         <tr>
#             <td>2</td>
#             <td>ReLU</td>
#             <td>-</td>
#         </tr>
#         <tr>
#             <td>3</td>
#             <td><a href="https://pytorch.org/docs/stable/generated/torch.nn.Conv1d.html">1D convolution</a></td>
#             <td>$256$ output channels and the same kernel size as the <i>1D convolution</i> at position $1$</td>
#         </tr>
#         <tr>
#             <td>4</td>
#             <td>ReLU</td>
#             <td>-</td>
#         </tr>
#         <tr>
#             <td>5</td>
#             <td><a href="https://pytorch.org/docs/stable/generated/torch.nn.Linear.html">fully connected</a></td>
#             <td><code>num_targets</code> output features (as specified during the data set creation)</td>
#         </tr>
#         <tr>
#             <td>6</td>
#             <td>output</td>
#             <td>-</td>
#         </tr>
#     </table>
#     <ul>
#         <li>Train a <code>CNN</code> network for $12$ epochs (use <code>Adam</code> optimizer with a learning rate of $0.01$), print the training accuracy as well as the loss per epoch and report the final test set loss and accuracy as well as the number of trainable parameters (use <code>count_parameters</code> from above). Use a <i>kernel size</i> of $1$.</li>
#         <li>Repeat the same procedure with a second <code>CNN</code> but a <i>kernel size</i> of $3$.</li>
#         <li>Hints:</li>
#         <ul>
#             <li>With the parameterized kernel size, you cannot hard-code the flattened number of elements for the linear layer input. Instead, you have to calculate it using the length of the input (<code>data_latch.num_instances</code>), which might be a good idea to pass into <code>__init__</code> as well. Each convolutional layer then reduces this length by <code>kernel_size - 1</code>.</li>
#             <li><code>Conv1d</code> expects the minibatch input shape <code>(N, C, L)</code>, but the latch data has a minibatch shape of <code>(N, L, C)</code>. Thus, in your <code>forward</code> method, you will first have to transform the input minibtach into the correct shape before you can apply the network architecture. There are several ways to do this, e.g., <a href="https://pytorch.org/docs/stable/generated/torch.transpose.html">transposing</a> or <a href="https://pytorch.org/docs/stable/generated/torch.movedim.html">moving dimensions</a>.</li>
#         </ul>
#     </ul>
# </div>

# %%
# your code goes here
class CNN(torch.nn.Module):
    
    def __init__(self, input_size, input_lenght, output_size, hidden_size, kernel_size):
        super().__init__()
        
        self.conv1 = torch.nn.Conv1d(input_size, hidden_size, kernel_size) 
        size_conv1 = input_lenght - (kernel_size - 1)
        
        self.conv2 = torch.nn.Conv1d(hidden_size, hidden_size, kernel_size)        
        size_conv2 = size_conv1 - (kernel_size - 1)
        
        self.fc = torch.nn.Linear(256*size_conv2, output_size)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = x.transpose(1,2)
        x = torch.relu(self.conv1(x))
        # x = x.view(x.size(0), -1)
        
        x = torch.relu(self.conv2(x))
        x = x.view(x.size(0), -1)
        
        return self.fc(x)

############################################################################

u3.set_seed(23)

def train_CNN(kernel_size):
    u3.set_seed(23)
    
    target_device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    cnn_model = CNN(
        input_size=data_latch.num_characters,
        input_lenght = data_latch.num_instances,
        output_size=data_latch.num_targets,
        hidden_size = 256,
        kernel_size = kernel_size
    )
    
    cnn_model = cnn_model.to(target_device)
    optimizer = torch.optim.Adam(cnn_model.parameters(), lr=0.01)
    
    num_epochs = 12
    nr_parameters = count_parameters(cnn_model)
    
    u3.set_seed(23)
    for epoch in range(num_epochs):
        u3.train_network(
            model=cnn_model,
            data_loader=data_loader_train,
            device=target_device,
            optimizer=optimizer
        )
        
        performance = u3.test_network(
            model=cnn_model,
            data_loader=data_loader_train,
            device=target_device
        )
        
        print(f'Epoch: {str(epoch + 1).zfill(len(str(num_epochs)))} ' +
              f'/ Loss: {performance[0]:.4f} / Accuracy: {performance[1]:.4f}')
    
    performance = u3.test_network(
        model=cnn_model,
        data_loader=data_loader_test,
        device=target_device
    )

    print(f'\nKernel = {kernel_size} \nFinal loss: {performance[0]:.4f} / Final accuracy: {performance[1]:.4f} \nUsed parameters: {nr_parameters} \n')
    
############################################################################

for i in [1,3]:
    train_CNN(i)
# Out:
# Epoch: 01 / Loss: 0.0510 / Accuracy: 0.0479
# Epoch: 02 / Loss: 0.0510 / Accuracy: 0.0479
# Epoch: 03 / Loss: 0.0510 / Accuracy: 0.0479
# Epoch: 04 / Loss: 0.0510 / Accuracy: 0.0479
# Epoch: 05 / Loss: 0.0510 / Accuracy: 0.0479
# Epoch: 06 / Loss: 0.0510 / Accuracy: 0.0470
# Epoch: 07 / Loss: 0.0510 / Accuracy: 0.0470
# Epoch: 08 / Loss: 0.0510 / Accuracy: 0.0470
# Epoch: 09 / Loss: 0.0510 / Accuracy: 0.0470
# Epoch: 10 / Loss: 0.0510 / Accuracy: 0.0479
# Epoch: 11 / Loss: 0.0510 / Accuracy: 0.0479
# Epoch: 12 / Loss: 0.0510 / Accuracy: 0.0479
#
# Kernel = 1
# Final loss: 0.0512 / Final accuracy: 0.0403
# Used parameters: 482329
#
# Epoch: 01 / Loss: 0.0504 / Accuracy: 0.0638
# Epoch: 02 / Loss: 0.0407 / Accuracy: 0.1684
# Epoch: 03 / Loss: 0.0287 / Accuracy: 0.4699
# Epoch: 04 / Loss: 0.0132 / Accuracy: 0.7733
# Epoch: 05 / Loss: 0.0059 / Accuracy: 0.9017
# Epoch: 06 / Loss: 0.0012 / Accuracy: 0.9875
# Epoch: 07 / Loss: 0.0008 / Accuracy: 0.9918
# Epoch: 08 / Loss: 0.0003 / Accuracy: 0.9969
# Epoch: 09 / Loss: 0.0001 / Accuracy: 0.9997
# Epoch: 10 / Loss: 0.0000 / Accuracy: 1.0000
# Epoch: 11 / Loss: 0.0000 / Accuracy: 1.0000
# Epoch: 12 / Loss: 0.0000 / Accuracy: 1.0000
#
# Kernel = 3
# Final loss: 0.0684 / Final accuracy: 0.3700
# Used parameters: 601113

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 2.3. [12 Points]</b>
#     <ul>
#         <li>Implement a class <code>PoolCNN</code> with the following architecture:</li>
#     </ul>
#     <table style="text-align:center;vertical-align:middle">
#         <th>Position</th>
#         <th>Element</th>
#         <th>Comment</th>
#         <tr>
#             <td>0</td>
#             <td>input</td>
#             <td>-</td>
#         </tr>
#         <tr>
#             <td>1</td>
#             <td><a href="https://pytorch.org/docs/stable/generated/torch.nn.Conv1d.html">1D convolution</a></td>
#             <td>$32$ output channels and a kernel size of $3$</td>
#         </tr>
#         <tr>
#             <td>2</td>
#             <td>ReLU</td>
#             <td>-</td>
#         </tr>
#         <tr>
#             <td>3</td>
#             <td><a href="https://pytorch.org/docs/stable/generated/torch.nn.AdaptiveMaxPool1d.html">1D adaptive max pool</a></td>
#             <td>output size of $1$</td>
#         </tr>
#         <tr>
#             <td>4</td>
#             <td><a href="https://pytorch.org/docs/stable/generated/torch.nn.Linear.html">fully connected</a></td>
#             <td><code>num_targets</code> output features (as specified during the data set creation)</td>
#         </tr>
#         <tr>
#             <td>5</td>
#             <td>output</td>
#             <td>-</td>
#         </tr>
#     </table>
#     <ul>
#         <li>Train a <code>PoolCNN</code> network for $10$ epochs (use <code>Adam</code> optimizer with a learning rate of $0.01$), print the training accuracy as well as the loss per epoch and report the final test set loss and accuracy as well as the number of trainable parameters.
#         <li>Compare the results of the <code>PoolCNN</code> network with those of the two <code>CNN</code> networks. What do you observe? Interpret and discuss your results regarding all three networks.</li>
#     </ul>
# </div>

# %%
# your code goes here

class PoolCNN(torch.nn.Module):
    
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.conv1 = torch.nn.Conv1d(input_size, hidden_size, 3) 
        self.pool = torch.nn.AdaptiveMaxPool1d(1)
        self.fc = torch.nn.Linear(hidden_size, output_size)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = x.transpose(1,2)
        x = torch.relu(self.conv1(x))

        x = self.pool(x)[..., 0]
        
        return self.fc(x)

############################################################################

u3.set_seed(23)

target_device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

cnn_model = PoolCNN(
    input_size=data_latch.num_characters,
    output_size=data_latch.num_targets,
    hidden_size = 32
)

cnn_model = cnn_model.to(target_device)
optimizer = torch.optim.Adam(cnn_model.parameters(), lr=0.01)

num_epochs = 10
nr_parameters = count_parameters(cnn_model)

u3.set_seed(23)

for epoch in range(num_epochs):
    u3.train_network(
        model=cnn_model,
        data_loader=data_loader_train,
        device=target_device,
        optimizer=optimizer
    )
    
    performance = u3.test_network(
        model=cnn_model,
        data_loader=data_loader_train,
        device=target_device
    )
    
    print(f'Epoch: {str(epoch + 1).zfill(len(str(num_epochs)))} ' +
          f'/ Loss: {performance[0]:.4f} / Accuracy: {performance[1]:.4f}')

performance = u3.test_network(
    model=cnn_model,
    data_loader=data_loader_test,
    device=target_device
)

print(f'\nKernel = 3 \nFinal loss: {performance[0]:.4f} / Final accuracy: {performance[1]:.4f} \nUsed parameters: {nr_parameters} \n')
# Out:
# Epoch: 01 / Loss: 0.0448 / Accuracy: 0.4059
# Epoch: 02 / Loss: 0.0063 / Accuracy: 0.9948
# Epoch: 03 / Loss: 0.0008 / Accuracy: 0.9973
# Epoch: 04 / Loss: 0.0004 / Accuracy: 0.9988
# Epoch: 05 / Loss: 0.0002 / Accuracy: 1.0000
# Epoch: 06 / Loss: 0.0002 / Accuracy: 1.0000
# Epoch: 07 / Loss: 0.0001 / Accuracy: 1.0000
# Epoch: 08 / Loss: 0.0001 / Accuracy: 1.0000
# Epoch: 09 / Loss: 0.0001 / Accuracy: 1.0000
# Epoch: 10 / Loss: 0.0001 / Accuracy: 1.0000
#
# Kernel = 3
# Final loss: 0.0001 / Final accuracy: 1.0000
# Used parameters: 3353

# %% [markdown]
# CNN with kernel=1 is pretty bad, it's as good as random guessing (4% accuracy), and it doesn't seem to learn at all.
#
# CNN with kernel=3 seems like a drastic change, it yields accuracy 1 on the training set, however that is due to overfitting, as the test set accuracy is 37% (much better than the previous, but still not good enough). The network is learning, but not well and quickly.
#
# PoolCNN with kernel=3 does perfectly. It is much faster and uses less parameters than the previous 2 and it yields perfect train and test set accuracy.

# %% [markdown]
# <div class="alert alert-warning">
#     The following code snippet is taken from the accompanying exercise notebook. You do not need to modify it for this assignment.
# </div>

# %%
def collect_gradients(model: torch.nn.Module, loader: torch.utils.data.DataLoader) -> pd.DataFrame:
    """
    Auxiliary function for collecting gradient magnitudes of a corresponding model w.r.t. the network input.
    
    :param model: model instance to be used for collecting gradients
    :param device: device to use for gradient collection
    :param loader: data loader supplying the samples used for collecting gradients
    :return: data frame comprising the gradient magnitudes of the loss function w.r.t. each input element
    """
    model_state = model.training
    model.train()
    model.zero_grad()
    
    # Set random seed for reproducibility (data iteration).
    u3.set_seed(23)
    
    # Iterating over the data set and computing the corresponding gradients.
    device, gradients = next(model.parameters())[0].device, []
    criterion = torch.nn.CrossEntropyLoss()
    for data, target in loader:
        data, target = data.float().to(device), target.long().to(device)
        
        # Prepare network input for gradient recording.
        data.requires_grad_(True)
        data.register_hook(lambda x: gradients.append(x.cpu().abs()))

        # One forward
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        model.zero_grad()
    
    # Reset model to its original state and return averaged collected gradients.
    model.train(mode=model_state)
    return pd.DataFrame(torch.cat(gradients, dim=0).mean(dim=2).numpy())

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 2.4. [8 Points]</b>
#     <ul>
#         <li>Create a <i>fresh</i> instance of <code>CNN</code> using a <i>kernel size</i> of $3$ and collect its gradients w.r.t. the network input using the latch sequence training set.</li>
#         <li>Visualize the collected gradients accordingly. What do you observe? Comment on your results.</li>
#     </ul>
# </div>

# %%
# your code goes here

u3.set_seed(23)

target_device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

cnn_model = CNN(
    input_size=data_latch.num_characters,
    input_lenght = data_latch.num_instances,
    output_size=data_latch.num_targets,
    hidden_size = 256,
    kernel_size = 3
)

cnn_model = cnn_model.to(target_device)

############################

gradient_data = collect_gradients(model=cnn_model, loader=data_loader_train)

############################
gradients_prepared = pd.melt(gradient_data, value_vars=gradient_data.columns)
gradients_prepared.columns = ('Instance', 'Gradient Magnitude')

# Define plotting figure and corresponding attributes.
fig, ax = plt.subplots(figsize=(20, 7))
ax.set_title('CNN with kernel 3 Gradient Magnitudes', fontsize=14)
ax.set(yscale='log')

# Plot pre-processed gradients.
sns.boxplot(x='Instance', y='Gradient Magnitude', data=gradients_prepared, ax=ax)
plt.show()

# %% [markdown]
# Gradients stay relatively stable throughout all timesteps, except a slight fall at the beginning and end.

# %% [markdown]
# <a name="exercise-latch-lstm"></a><h2>Tackling Sequence Data with LSTMs</h2>
# <p>During the accompanying exercise class, the <i>Long Short-Term Memory (LSTM)</i> was presented as a quite prominent and often used architecture in the recurrent case. It was designed and published by <a href="https://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.676.4320&rep=rep1&type=pdf">Hochreiter and Schmidhuber</a>:
#     <center>
#         <cite>
#             Hochreiter, S. and Schmidhuber, J., 1997. Long short-term memory. Neural computation, 9(8), pp.1735-1780.
#         </cite>
#     </center></p>
#
# <p>It has to be noted, that the most crucial part of the LSTM, the <i>constant error carousel (CEC)</i>, was already discussed during <a href="https://people.idsia.ch//~juergen/SeppHochreiter1991ThesisAdvisorSchmidhuber.pdf">Hochreiter's diploma thesis</a> (in German):
#     <center>
#             <cite>
#                 Hochreiter, S., 1991. Untersuchungen zu dynamischen neuronalen Netzen. Diploma, Technische Universität München, 91(1).
#             </cite>
#     </center></p>
#
# <p>In contrast to most other recurrent architectures like the Elman RNN, the <i>LSTM</i> is a bit more complex, but equally more powerful:
#     <center>
#         \begin{equation}
#             \begin{split}
#                 i_{t} &= \sigma{\left(W_{ii}x_{t} + b_{ii} + W_{hi}h_{t-1} + b_{hi}\right)} \\
#                 \color{red}{f_{t}} &\color{red}{= \sigma{\left(W_{if}x_{t} + b_{if} + W_{hf}h_{t-1} + b_{hf}\right)}} \\
#                 g_{t} &= \tanh{\left(W_{ig}x_{t} + b_{ig} + W_{hg}h_{t-1} + b_{hg}\right)} \\
#                 o_{t} &= \sigma{\left(W_{io}x_{t} + b_{io} + W_{ho}h_{t-1} + b_{ho}\right)} \\
#                 c_{t} &= \color{red}{f_{t}\odot{}}c_{t-1} + i_{t}\odot{}g_{t} \\
#                 h_{t} &= o_{t}\odot{}\tanh{\left(c_{t}\right)}
#             \end{split}
#         \end{equation}
#     </center></p>
#
# <p>We are using the implementation provided by PyTorch, more information may be found in the <a href="https://pytorch.org/docs/stable/generated/torch.nn.LSTM.html?highlight=lstm#torch.nn.LSTM">official documentation</a>. It has to be noted, the the <i>original</i> formulation did <i>not</i> contain an additional <i>forget gate</i> $f_{t}$ (see equations above), as this completely destroys the <i>constant error carousel</i> – it was introduced by <a href="https://www.mitpressjournals.org/doi/pdfplus/10.1162/089976600300015015">Gers et al.</a>:
# <center>
#     <cite>Gers, F.A., Schmidhuber, J. and Cummins, F., 1999. Learning to forget: Continual prediction with LSTM.
#     </cite>
# </center></p>
# <p>Nonetheless, for <i>some</i> tasks, the forget gate seems to provide a useful addition. Hence, in this exercise you'll be tasked with activating the <i>forget gate</i> and interpreting the results.</p>

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 3.1. [13 Points]</b>
#     <ul>
#         <li>Implement a class <code>LSTM</code> with the following architecture:</li>
#     </ul>
#     <table style="text-align:center;vertical-align:middle">
#         <th>Position</th>
#         <th>Element</th>
#         <th>Comment</th>
#         <tr>
#             <td>0</td>
#             <td>input</td>
#             <td>-</td>
#         </tr>
#         <tr>
#             <td>1</td>
#             <td><a href="https://pytorch.org/docs/stable/generated/torch.nn.LSTM.html">LSTM</a></td>
#             <td>$32$ memory cells and a configurable initial forget gate bias (specified as an argument to <code>__init__</code>)</td>
#         </tr>
#         <tr>
#             <td>2</td>
#             <td><a href="https://pytorch.org/docs/stable/generated/torch.nn.Linear.html">fully connected</a></td>
#             <td><code>num_targets</code> output features (as specified during the data set creation)</td>
#         </tr>
#         <tr>
#             <td>3</td>
#             <td>output</td>
#             <td>-</td>
#         </tr>
#     </table>
#     <ul>
#         <li>Train an <code>LSTM</code> network for $15$ epochs (use <code>Adam</code> optimizer with a learning rate of $0.01$), print the training accuracy as well as the loss per epoch and report the final test set loss and accuracy as well as the number of trainable parameters. Use an initial forget gate bias of $0.0$. Do you expect the resulting performance?</li>
#         <li>Hint: You now want to use the forget gate, so do <i>not</i> disable the gradient computation!</li>
#     </ul>
# </div>

# %%
# your code goes here
class LSTM(torch.nn.Module):    
    def __init__(self, input_size: int, bias, hidden_size, output_size):
        super().__init__()
        self.lstm1 = torch.nn.LSTM(input_size, hidden_size, batch_first=True)
        self.fc1 = torch.nn.Linear(self.lstm1.hidden_size, output_size)
        
        for name, parameter in self.lstm1.named_parameters():
            if 'bias' in name:
                # From the documentation (analogous for hidden-hidden bias):
                # bias_ih_l[k] – the learnable input-hidden bias of the k-th layer (b_ii|b_if|b_ig|b_io), of shape (4*hidden_size)
                # This results in the following indices/slices (hidden_size abbreviated to just h):
                # (b_ii|b_if|b_ig|b_io)
                #  ^    ^    ^    ^
                #  |    |    |    3*h:4*h
                #  |    |    2*h:3*h
                #  |    h:2*h
                #  0:h
                # We are interested in the forget gate bias b_if, so we need the slice h:2*h
                # (equal to (parameter.shape[0] // 4):(parameter.shape[0] // 2))
                # Use large bias value to always let information pass through the forget gate
                parameter.data[hidden_size:2 * hidden_size].fill_(bias)
                # parameter.register_hook(_reset_forget_gate_hook)
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # Return value of torch.nn.LSTM invocation is a 2-tuple of:
        # [0] = full output tensor
        # [1] = 2-tuple of:
        #       [0] = final hidden state tensor
        #       [1] = final cell state tensor
        x = self.lstm1(x)[1][0].squeeze()
        return self.fc1(x)


##################################################
u3.set_seed(23)

# Create LSTM instance and the corresponding optimizer to use.
target_device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
lstm_model = LSTM(
    input_size=32,
    output_size=data_latch.num_targets,
    hidden_size = 32,
    bias = 0.0
)
lstm_model = lstm_model.to(target_device)
optimizer = torch.optim.Adam(lstm_model.parameters(), lr=0.01)

# Print the architecture of the LSTM instance.
print(lstm_model, end='\n\n')

# Set random seed for reproducibility (data iteration).
u3.set_seed(23)
nr_parameters = count_parameters(lstm_model)
# Train and evaluate LSTM instance on the latch sequence training set.
num_epochs = 15
for epoch in range(num_epochs):
    # Train LSTM instance for one epoch.
    u3.train_network(
        model=lstm_model,
        data_loader=data_loader_train,
        device=target_device,
        optimizer=optimizer
    )
    
    # Evaluate current LSTM instance.
    performance = u3.test_network(
        model=lstm_model,
        data_loader=data_loader_train,
        device=target_device
    )
    
    # Print result of current epoch to standard out.
    print(f'Epoch: {str(epoch + 1).zfill(len(str(num_epochs)))} ' +
          f'/ Loss: {performance[0]:.4f} / Accuracy: {performance[1]:.4f}')

# Evaluate final model on test data set.
performance = u3.test_network(
    model=lstm_model,
    data_loader=data_loader_test,
    device=target_device
)
print(f'\nFinal loss: {performance[0]:.4f} / Final accuracy: {performance[1]:.4f} \nUsed parameters: {nr_parameters} \n')
print('Yes, I expected a good performance.')
# Out:
# LSTM(
#   (lstm1): LSTM(32, 32, batch_first=True)
#   (fc1): Linear(in_features=32, out_features=25, bias=True)
# )
#
# Epoch: 01 / Loss: 0.0509 / Accuracy: 0.0491
# Epoch: 02 / Loss: 0.0504 / Accuracy: 0.0720
# Epoch: 03 / Loss: 0.0497 / Accuracy: 0.0891
# Epoch: 04 / Loss: 0.0487 / Accuracy: 0.1105
# Epoch: 05 / Loss: 0.0427 / Accuracy: 0.1816
# Epoch: 06 / Loss: 0.0372 / Accuracy: 0.2124
# Epoch: 07 / Loss: 0.0305 / Accuracy: 0.3195
# Epoch: 08 / Loss: 0.0301 / Accuracy: 0.3973
# Epoch: 09 / Loss: 0.0227 / Accuracy: 0.5285
# Epoch: 10 / Loss: 0.0218 / Accuracy: 0.6146
# Epoch: 11 / Loss: 0.0023 / Accuracy: 0.9887
# Epoch: 12 / Loss: 0.0006 / Accuracy: 0.9991
# Epoch: 13 / Loss: 0.0004 / Accuracy: 1.0000
# Epoch: 14 / Loss: 0.0049 / Accuracy: 0.8837
# Epoch: 15 / Loss: 0.0021 / Accuracy: 0.9664
#
# Final loss: 0.0017 / Final accuracy: 0.9731
# Used parameters: 9273
#
# Yes, I expected a good performance.

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 3.2. [10 Points]</b>
#     <ul>
#         <li>Create a <i>fresh</i> instance of <code>LSTM</code> and collect its gradients w.r.t. the network input using the latch sequence training set.</li>
#         <li>Visualize the collected gradients accordingly. What do you observe? Comment on your results.</li>
#     </ul>
# </div>

# %%
# your code goes here
u3.set_seed(23)

target_device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

lstm_model_fresh = LSTM(
    input_size=32,
    output_size=data_latch.num_targets,
    hidden_size = 32,
    bias = 0.0
)

lstm_model_fresh = lstm_model_fresh.to(target_device)

############################

gradient_data_fresh = collect_gradients(model=lstm_model_fresh, loader=data_loader_train)

############################
gradients_prepared = pd.melt(gradient_data_fresh, value_vars=gradient_data.columns)
gradients_prepared.columns = ('Timestep', 'Gradient Magnitude')

# Define plotting figure and corresponding attributes.
fig, ax = plt.subplots(figsize=(20, 7))
ax.set_title('LSTM Gradient Magnitudes', fontsize=14)
ax.set(yscale='log')

# Plot pre-processed gradients.
sns.boxplot(x='Timestep', y='Gradient Magnitude', data=gradients_prepared, ax=ax)
plt.show()

# %% [markdown]
# It's an untrained network, so the special architecture of LSTMs doesn't do anything here. Gradient vanishes.

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 3.3. [10 Points]</b>
#     <ul>
#         <li>Use the already trained <code>LSTM</code> instance from the beginning of this section for collecting its gradients w.r.t. the network input using the latch sequence training set, i.e., collect gradients one more time but now using the trained model.</li>
#         <li>Visualize (in a single plot) the the newly collected gradients together with the previous gradients of the <i>freshly</i> created <code>LSTM</code> instance. What do you observe? Comment on your results.</li>
#     </ul>
# </div>

# %%
# your code goes here
gradient_data = collect_gradients(model=lstm_model, loader=data_loader_train)

############################

gradients = [gradient_data, gradient_data_fresh]

models = ['Trained LSTM', 'Untrained LSTM']
gradients_prepared = []
for model, gradient in zip(models, gradients):
    gradients_prepared.append(pd.melt(gradient, value_vars=gradient.columns))
    gradients_prepared[-1].columns = ('Timestep', 'Gradient Magnitude')
    gradients_prepared[-1]['Architecture'] = model

# Combine all gradients in a single data frame.
gradients_prepared = pd.concat(gradients_prepared)

# Define plotting figure and corresponding attributes.
fig, ax = plt.subplots(figsize=(20, 7))
ax.set_title('Gradient Magnitudes', fontsize=14)
ax.set(yscale='log')

# Plot pre-processed gradients.
sns.boxplot(x='Timestep', y='Gradient Magnitude', hue='Architecture', data=gradients_prepared, ax=ax)
plt.show()

# %% [markdown]
# In the trained LSTM, the one we used before, the gradient stays stable and does not exponentially decrease, does not vanish. These are good results.

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 3.4. [10 Points]</b>
#     <ul>
#         <li>Train an <code>LSTM</code> network for $15$ epochs (use <code>Adam</code> optimizer with a learning rate of $0.01$), print the training accuracy as well as the loss per epoch and report the final test set loss and accuracy as well as the number of trainable parameters. Use an initial forget gate bias of $1.0$. Do you expect the resulting performance?</li>
#         <li>Analogous to above, visualize (in a single plot) the gradients of both a <i>freshly</i> created <code>LSTM</code> instance and the trained model. What do you observe? Comment on your results.</li>
#     </ul>
# </div>

# %%
# your code goes here
u3.set_seed(23)

# Create LSTM instance and the corresponding optimizer to use.
target_device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
lstm_model2 = LSTM(
    input_size=32,
    output_size=data_latch.num_targets,
    hidden_size = 32,
    bias = 1.0
)
lstm_model2 = lstm_model2.to(target_device)
optimizer = torch.optim.Adam(lstm_model2.parameters(), lr=0.01)

# Print the architecture of the LSTM instance.
print(lstm_model2, end='\n\n')

# Set random seed for reproducibility (data iteration).
u3.set_seed(23)
nr_parameters = count_parameters(lstm_model2)
# Train and evaluate LSTM instance on the latch sequence training set.
num_epochs = 15
for epoch in range(num_epochs):
    # Train LSTM instance for one epoch.
    u3.train_network(
        model=lstm_model2,
        data_loader=data_loader_train,
        device=target_device,
        optimizer=optimizer
    )
    
    # Evaluate current LSTM instance.
    performance = u3.test_network(
        model=lstm_model,
        data_loader=data_loader_train,
        device=target_device
    )
    
    # Print result of current epoch to standard out.
    print(f'Epoch: {str(epoch + 1).zfill(len(str(num_epochs)))} ' +
          f'/ Loss: {performance[0]:.4f} / Accuracy: {performance[1]:.4f}')

# Evaluate final model on test data set.
performance = u3.test_network(
    model=lstm_model2,
    data_loader=data_loader_test,
    device=target_device
)
print(f'\nFinal loss: {performance[0]:.4f} / Final accuracy: {performance[1]:.4f} \nUsed parameters: {nr_parameters} \n')

gradient_data2 = collect_gradients(model=lstm_model2, loader=data_loader_train)

################################################

u3.set_seed(23)

target_device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

lstm_model2_fresh = LSTM(
    input_size=32,
    output_size=data_latch.num_targets,
    hidden_size = 32,
    bias = 1.0
)

lstm_model2_fresh = lstm_model2_fresh.to(target_device)

gradient_data2_fresh = collect_gradients(model=lstm_model2_fresh, loader=data_loader_train)

################################################

gradients = [gradient_data2, gradient_data2_fresh]

models = ['Trained LSTM', 'Untrained LSTM']
gradients_prepared = []
for model, gradient in zip(models, gradients):
    gradients_prepared.append(pd.melt(gradient, value_vars=gradient.columns))
    gradients_prepared[-1].columns = ('Timestep', 'Gradient Magnitude')
    gradients_prepared[-1]['Architecture'] = model

# Combine all gradients in a single data frame.
gradients_prepared = pd.concat(gradients_prepared)

# Define plotting figure and corresponding attributes.
fig, ax = plt.subplots(figsize=(25, 7))
ax.set_title('Gradient Magnitudes', fontsize=14)
ax.set(yscale='log')

# Plot pre-processed gradients.
sns.boxplot(x='Timestep', y='Gradient Magnitude', hue='Architecture', data=gradients_prepared, ax=ax)
plt.show()
# Out:
# LSTM(
#   (lstm1): LSTM(32, 32, batch_first=True)
#   (fc1): Linear(in_features=32, out_features=25, bias=True)
# )
#
# Epoch: 01 / Loss: 0.0021 / Accuracy: 0.9664
# Epoch: 02 / Loss: 0.0020 / Accuracy: 0.9664
# Epoch: 03 / Loss: 0.0020 / Accuracy: 0.9664
# Epoch: 04 / Loss: 0.0020 / Accuracy: 0.9664
# Epoch: 05 / Loss: 0.0020 / Accuracy: 0.9664
# Epoch: 06 / Loss: 0.0020 / Accuracy: 0.9664
# Epoch: 07 / Loss: 0.0020 / Accuracy: 0.9664
# Epoch: 08 / Loss: 0.0021 / Accuracy: 0.9664
# Epoch: 09 / Loss: 0.0020 / Accuracy: 0.9664
# Epoch: 10 / Loss: 0.0020 / Accuracy: 0.9664
# Epoch: 11 / Loss: 0.0020 / Accuracy: 0.9664
# Epoch: 12 / Loss: 0.0020 / Accuracy: 0.9664
# Epoch: 13 / Loss: 0.0021 / Accuracy: 0.9664
# Epoch: 14 / Loss: 0.0021 / Accuracy: 0.9664
# Epoch: 15 / Loss: 0.0021 / Accuracy: 0.9664
#
# Final loss: 0.0002 / Final accuracy: 1.0000
# Used parameters: 9273

# %% [markdown]
# The gradients for this case are much more stable for the fresh case. The network does much better, indicating the bias=1.0 is a better choice in our case. The gradients also stay relatively stable for the trained LSTM case.
